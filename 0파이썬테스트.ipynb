# %% [markdown]
# # 파이썬 테스트

# %%
print("hello python")
# Out:
# hello python

# %%
# 파이썬 버전 확인
# %%python --version

# 매직 커멘드 사용
# Out:
# Python 3.12.11

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
input()
# Out:
# 안뇽
# '안뇽'

# %%
input("숫자를 입력하세요. > ")
# Out:
# 숫자를 입력하세요. > 26
# '26'

# %%
num = input("숫자를 입력하세요. > ")
# Out:
# 숫자를 입력하세요. > 5

# %%
num
# Out:
# '5'

# %%
# int 정수형
type(7)
# Out:
# int

# %%
# str 문자형
type(num)
# Out:
# str

# %%
# 형 변환(casting) : 문자 > 숫자(정수)
num = int(num)
print(type(num))
print
# Out:
# <class 'int'>

# %%
# 단축키
# 코드 셸에서 > 문자 셀 : ctrl + m > m
# 문자 셸에서 > 문자 셀 : ctrl + m > y

# %% [markdown]
# # 파이썬의 기본 자료형
# - 기본자료형 : 한번에 하나의 값만 변수에 저장
# - 숫자 : int, float
# - 문자 : str
# - 불(bool) : bool

# %%
num_f = 20.0
type(num_f)
# Out:
# float

# %% [markdown]
# # 사칙연산

# %%
num1 = input("숫자1")
num2 = input("숫자2")
# Out:
# 숫자120
# 숫자230

# %%
result = int(num1) + int(num2)

# %%
result / 5
# Out:
# 10.0

# %%
num1 = int(num1)
num2 = int(num2)

# %%
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
9print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
print(-num1)
print(num1 ** num2)
print(abs(num1))
# Out:
# 50
# -10
# 600
# 0.6666666666666666
# 0
# 20
# -20
# 1073741824000000000000000000000000000000
# 20

# %% [markdown]
# # 연산 라이브러리

# %% [markdown]
# 내장 라이브러리
#
# *   파이썬 설치하면 함께 설치됨
# *   선언 없이 사용한 경우 : print(), input, abs()
#
#
# 선언을 해야하는 경우 : math,lib os,sys
#
# *   외장 라이브러리
# *   따로 설치 해야함
# *   pip install numpy

# %%
import math

# %%
math.
