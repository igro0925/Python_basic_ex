# %% [markdown]
# # <font color='red'> *실습* </font>
# # <font color='red'> DICTIONARIES AND BOOLEANS </font>

# %% [markdown]
# # <font color='blue'> 1. 밸류들을 전부 곱한 값을 출력하는 코드를 만드세요. </font>

# %%
my_dict = {'data1':500,
           'data2':-10,
           'data3':300}

# %%
value = list(my_dict.values())
value
# Out:
# [500, -10, 300]

# %%
result = 1
for i in range(len(value)):
  result = result*value[i]
result
# Out:
# -1500000

# %% [markdown]
# # <font color='blue'> 2. 각 학생별로, 중간과 기말의 평균점수를 구하세요.

# %%
student_details = [
  {'student_id' : 1, 'subject' : 'math', 'midterm' : 60, 'final' : 85},
  {'student_id' : 2, 'subject' : 'math', 'midterm' : 80, 'final' : 78},
  {'student_id' : 3, 'subject' : 'math', 'midterm' : 90, 'final' : 85}
]

# %%
# [] 대괄호 시작 대괄호로 끝나는 것을 리스트라고 함.
# {} 중괄호로 시작 중괄호로 끝나는 것을 딕셔너리라고 함.

# %%
# 강사님 풀이
# 한 학생의 중간성적 추출, 기말성적 추출 아직 for문 안배워서 하나씩 하는듯
st1_avg = (student_details[0]['midterm'] + student_details[0]['final'])/2

# %%
student_details[1].values()
# Out:
# dict_values([2, 'math', 80, 78])

# %%
for i in range(len(student_details)):
  print(i , "번 학생의 중간 기말 평균점수는 ",(student_details[i]["midterm"]+student_details[i]["final"])/2,  "입니다.")
# Out:
# 0 번 학생의 중간 기말 평균점수는  72.5 입니다.
# 1 번 학생의 중간 기말 평균점수는  79.0 입니다.
# 2 번 학생의 중간 기말 평균점수는  87.5 입니다.
# {}

# %% [markdown]
# # <font color='blue'> 3. 위에서 구한 평균점수를,"AVERAGE" 라는 키를 새로 만들어서, 각 학생의 딕셔너리에 추가하세요.

# %%
for i in range(len(student_details)):
  student_details[i]["average"] = (student_details[i]["midterm"] + student_details[i]["final"])/2
student_details
# Out:
# [{'student_id': 1,
#   'subject': 'math',
#   'midterm': 60,
#   'final': 85,
#   'average': 72.5},
#  {'student_id': 2,
#   'subject': 'math',
#   'midterm': 80,
#   'final': 78,
#   'average': 79.0},
#  {'student_id': 3,
#   'subject': 'math',
#   'midterm': 90,
#   'final': 85,
#   'average': 87.5}]

# %% [markdown]
# # <font color='blue'> 4. 각각의 숫자를,  제곱한 값으로 바꾸세요.

# %%
for i in range(len(student_details)):
  student_details[i]["average"] = student_details[i]["average"] * student_details[i]["average"]
student_details
# Out:
# [{'student_id': 1,
#   'subject': 'math',
#   'midterm': 60,
#   'final': 85,
#   'average': 5256.25},
#  {'student_id': 2,
#   'subject': 'math',
#   'midterm': 80,
#   'final': 78,
#   'average': 6241.0},
#  {'student_id': 3,
#   'subject': 'math',
#   'midterm': 90,
#   'final': 85,
#   'average': 7656.25}]

# %%
dictionary = {'C1' : [10,20,30],
              'C2' : [20,30,40]}

# %%
# C1 : 첫번째 요소 제곱하기
dictionary["C1"]
# Out:
# [10, 20, 30]

# %%
dictionary["C1"] = [dictionary["C1"][0]**2, dictionary["C1"][1]**2, dictionary["C1"][2]**2]
dictionary["C1"]
# Out:
# [100, 400, 900]

# %%
dictionary["C2"] = [dictionary["C2"][0]**2, dictionary["C2"][1]**2, dictionary["C2"][2]**2]
dictionary
# Out:
# {'C1': [100, 400, 900], 'C2': [160000, 810000, 2560000]}

# %%
dictionary.values()
# Out:
# dict_values([[10, 20, 30], [20, 30, 40]])

# %% [markdown]
# # <font color='blue'>  5. (1)모든 키를 리스트로 출력하세요. (2) 모든 밸류를 리스트로 출력하세요. (3) 모든 밸류의 값을 다 더하세요.

# %%
my_salary = {"alex": 25, "sally": 28, "dina": 30}
list(my_salary.keys())
# Out:
# ['alex', 'sally', 'dina']

# %%
list(my_salary.values())
# Out:
# [25, 28, 30]

# %%
# 자주 기억하자
sum(my_salary_value)
# Out:
# 83

# %%
result = 0
for i in range(len(my_salary_value)):
  result = result + my_salary_value[i]
result
# Out:
# 83

# %% [markdown]
# # <font color='blue'>  6. (a)딕셔너리의 길이를 구하세요.  (b) 나이에 대한 오름차순으로 정렬하세요.

# %%
my_dict = {"sally": 23, "dina": 22, "holy": 50, "Joe": 10, "Peter": 44}

# %%
len(my_dict)
# Out:
# 5

# %%
# 딕셔너리는 순서가 딱히 없어서 값만 오름차순으로 정렬했음
sorted(my_dict.values())
# Out:
# [10, 22, 23, 44, 50]

# %%
sorted_dict = dict(sorted(my_dict.items(), key=lambda x: x[1]))
sorted_dict
# Out:
# {'Joe': 10, 'dina': 22, 'sally': 23, 'Peter': 44, 'holy': 50}
