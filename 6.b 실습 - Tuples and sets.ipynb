# %% [markdown]
# # <font color='red'> *실습* </font>
# # <font color='red'> SETS AND TUPLES </font>

# %% [markdown]
# ## 변수
# - 자료를 저장한 메모리를 불러온다.
#
# # 자료의 타입
# ## 기본 자료형
# -문자형(str)
# -정수형(int)
# -실수형(float)
#
# ## 컨테이너 자료형
# 하나의 변수가 여러개의 자료를 식별할 수 있다.
# - list : index참조
# - dict : key참조
# - tuple : index 참조. 요소 수정 불가 immutable하다
# - set : 값의 중복을 허용하지 않음

# %%
# 변수는 숫자로 시작 안됨, 문자로 시작, 한글도 가능
# 특수문자 안돼, _(underscore = underbar)는 가능함
# 변수명은 직관적으로
# 두 단어를 연결 할 때는 언더바를 사용하는데 이를 스네이크 표기라고 말함
# numCount <- 카멜 표기법 : 함수명에 사용
# numCount <- 카멜 표기법 : 클래스에 사용

Num_Count = 3

# %% [markdown]
# # <font color='blue'> 1. 다음처럼 출력하세요. Hello Chanel, you are 26 years old!

# %%
my_tuple = ("Chanel", 26)
print("Hello "+ my_tuple[0]+", you are", my_tuple[1],"years old!")
# Out:
# Hello Chanel, you are 26 years old!

# %%
# Hello Chanel, you are 26 years old!
# format문 활용
f"Hello {my_tuple[0]}, you are {my_tuple[1]} years old!"
# Out:
# 'Hello chanel, you are mitch years old!'

# %% [markdown]
# # <font color='blue'> 2. 다음과 같은 튜플이 있습니다. (1) 모든 튜플 출력, (2) 마지막 값 출력, (2) 첫번째와 두번째 값 출력

# %%
my_tuple = ("chanel", "mitch", "sarah", "cynthia", "diane", "steeve")

# %%
my_tuple
# Out:
# ('chanel', 'mitch', 'sarah', 'cynthia', 'diane', 'steeve')

# %%
my_tuple[len(my_tuple)-1]
# my_tuple[-1] 이게 더 간단
# Out:
# 'steeve'

# %%
my_tuple[:2]
# my_tuple[0:1+1] 현업에서 이렇게 요구하는 곳도 있음
# Out:
# ('chanel', 'mitch')

# %%
list(my_tuple[:2])
# Out:
# ['chanel', 'mitch']

# %% [markdown]
# #  <font color='blue'> 3. 다음과 같은 튜플이 있습니다. (1) 길이를 구하세요. (2) 타입을 확인하세요.

# %%
my_tuple = ("Ryan", "ahmed", 25)

# %%
len(my_tuple)
# Out:
# 3

# %%
type(my_tuple)
# Out:
# tuple

# %% [markdown]
# # <font color='blue'> 4. (1) "40"을 출력하세요, (2) "world"를 출력하세요, (3) 25 를 출력하세요, (4) 두번째 요소로 저장되어 있는 리스트를 출력하세요,(5) 맨 마지막 요소인 튜플을 출력하세요

# %%
my_tuple = ("hello", [87, 40, 60], "world", (10, 25, 30))

# %%
my_tuple[1][1]
# Out:
# 40

# %%
my_tuple[2]
# Out:
# 'world'

# %%
my_tuple[3]
# Out:
# (10, 25, 30)

# %%
my_tuple[3][1]
# Out:
# int

# %%
list(my_tuple[1])
# Out:
# [87, 40, 60]

# %%
my_tuple[-1]
# Out:
# (10, 25, 30)

# %% [markdown]
# # <font color='blue'> 5. (1) python 이 들어 있는지 확인하세요. (2) Python 이 들어 있는지 확인하세요. (3) physics 가 없는지 확인하세요.

# %%
my_tuple = ('math','science','science','python','english')

# %%
"python" in my_tuple
# Out:
# True

# %%
"Python" in my_tuple
# Out:
# False

# %%
"physics" in my_tuple
# Out:
# False

# %% [markdown]
# # <font color='blue'> 6. my_list에는 동일한 값들이 들어있습니다. 동일한 값들을 제거하여, 유니크한 값들의 리스트로 만드세요.  </font>

# %%
my_list = ["2", 50, "2", 50, 4, 6, 9, 9]

# %%
list(set(my_list))
# Out:
# [4, 6, '2', 9, 50]

# %% [markdown]
# #  <font color='blue'> 9. 자신의 이름을 추가하세요. 그리고 출력하세요.

# %%
my_set = {"sara", "mike", "jon", "jon", "mike"}
my_set
# Out:
# {'jon', 'mike', 'sara'}

# %%
names = list(my_set)

# %%
names.append("kms")

# %%
names
# Out:
# ['sara', 'mike', 'jon', 'kms']

# %%
# 한번에도 됨
my_set.add("joy")
my_set
# Out:
# {'jon', 'joy', 'mike', 'sara'}
